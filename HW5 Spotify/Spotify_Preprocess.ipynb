# %% [markdown]
# # DS 4300 HW 5 Spotify
#
# ### Sampling and Preprocessing

# %%
import pandas as pd
import numpy as np
import itertools
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# read the data
data = pd.read_csv('spotify.csv')
data.track_name = data.track_name.str.replace("'","")

# sample the data (top 50 popular songs of each genre)
n = 20
sample = data.groupby('track_genre', group_keys=False).apply(lambda x: x.sort_values(by='popularity',ascending=False).head(n))

# scale the numeric data
scaler = MinMaxScaler()
scaled = pd.DataFrame(scaler.fit_transform(sample.iloc[:, 5:-1]), columns=sample.iloc[:, 5:-1].columns)

# retrieve relevant columns
song_data = sample.iloc[:, [1,2,3,4,-1]].reset_index()
scaled_data = scaled.loc[:, ['valence', 'tempo', 'popularity']]
df = pd.merge(song_data, scaled_data, left_index=True, right_index=True)

# drop nulls and encode categorical variables
df = df.dropna()
df = df.drop_duplicates(subset=['artists', 'track_name'])

df.head(5)
# Out:
# /Users/avrilfiellemauro/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/avrilfiellemauro/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/avrilfiellemauro/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /Users/avrilfiellemauro/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/avrilfiellemauro/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/avrilfiellemauro/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
#    index                track_id                               artists  \
# 0      4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 1      7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 3     60  08MFgEQeVLF37EyZ7jcwLc                          Zack Tabudlo
# 4     10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# 5      6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
#
#                             album_name            track_name track_genre  \
# 0                              Hold On               Hold On    acoustic
# 1  We Sing. We Dance. We Steal Things.              Im Yours    acoustic
# 3                                 Pano                  Pano    acoustic
# 4                              Episode  Give Me Your Forever    acoustic
# 5          Is There Anybody Out There?         Say Something    acoustic
#
#     valence     tempo  popularity
# 0  0.170582  0.572393    0.793103
# 1  0.727273  0.720377    0.770115
# 3  0.423902  0.834327    0.712644
# 4  0.307457  0.476744    0.701149
# 5  0.078141  0.674203    0.701149

# %%
df[df.artists == 'The Strokes']
# Out:
#      index                track_id      artists        album_name  \
# 769  38015  5ruzrDWcT0vuJIOMW7gMnW  The Strokes  The New Abnormal
# 777  38086  57Xjny5yNzAcsxnusKmAfA  The Strokes      Room On Fire
# 779  38074  7kzKAuUzOITUauHAhoMoxA  The Strokes        Is This It
#
#                  track_name track_genre   valence     tempo  popularity
# 769  The Adults Are Talking      garage  0.662921  0.787180    0.758621
# 777                Reptilia      garage  0.786517  0.754014    0.712644
# 779               Last Nite      garage  0.783453  0.496485    0.701149

# %% [markdown]
# ### Similarity Scores

# %%
# assemble features
encoded_df = pd.get_dummies(df, columns=['track_genre'])
features = encoded_df.iloc[:,5:]
features.shape

# compute similarity scores
cosine_sim = cosine_similarity(features, features)
cosine_sim_df = pd.DataFrame(cosine_sim, index=df.track_id, columns=df.track_id)
cosine_sim_df.head(5)
# Out:
# track_id                5vjLSffimiIP26QG5WcN2K  1EzrEOXmMH3G43AXT1y7pA  \
# track_id
# 5vjLSffimiIP26QG5WcN2K                1.000000                0.937620
# 1EzrEOXmMH3G43AXT1y7pA                0.937620                1.000000
# 08MFgEQeVLF37EyZ7jcwLc                0.972169                0.979727
# 4mzP5mHkRvGxdhdGdAH7EJ                0.991455                0.962800
# 6Vc5wAMmXdKIAM7WUoEb7N                0.993087                0.917130
#
# track_id                08MFgEQeVLF37EyZ7jcwLc  4mzP5mHkRvGxdhdGdAH7EJ  \
# track_id
# 5vjLSffimiIP26QG5WcN2K                0
# track_id
# 5vjLSffimiIP26QG5WcN2K                0.473860                0.444770
# 1EzrEOXmMH3G43AXT1y7pA                0.509158                0.452082
# 08MFgEQeVLF37EyZ7jcwLc                0.534134                0.477902
# 4mzP5mHkRvGxdhdGdAH7EJ                0.443357                0.411154
# 6Vc5wAMmXdKIAM7WUoEb7N                0.483875                0.449056
#
# [5 rows x 1828 columns]

# %%
def unique_combinations(elements):
    return list(itertools.combinations(elements, 2))

track_pairs = unique_combinations(df.track_id.values)
sim_df = pd.DataFrame(track_pairs, columns=['track1', 'track2'])
sim_df['simscore'] = [cosine_sim_df[x][y] for x,y in track_pairs]
sim_df.head(5)
# Out:
#                    track1                  track2  simscore
# 0  5vjLSffimiIP26QG5WcN2K  1EzrEOXmMH3G43AXT1y7pA  0.937620
# 1  5vjLSffimiIP26QG5WcN2K  08MFgEQeVLF37EyZ7jcwLc  0.972169
# 2  5vjLSffimiIP26QG5WcN2K  4mzP5mHkRvGxdhdGdAH7EJ  0.991455
# 3  5vjLSffimiIP26QG5WcN2K  6Vc5wAMmXdKIAM7WUoEb7N  0.993087
# 4  5vjLSffimiIP26QG5WcN2K  0IktbUcnAGrvD03AWnz3Q8  0.940001

# %%
song_df = df.iloc[:, 1:6]

sim_df = pd.merge(sim_df, song_df, 
                  left_on='track1', 
                  right_on="track_id").drop('track_id', axis=1).rename(columns={'track_name':'song1',
                                                                                'track_genre': 'genre1',
                                                                                'album_name': 'album1',
                                                                                'artists': 'artists1'})
sim_df = pd.merge(sim_df, song_df, 
                  left_on='track2', 
                  right_on="track_id").drop('track_id', axis=1).rename(columns={'track_name':'song2',
                                                                                'track_genre': 'genre2',
                                                                                'album_name': 'album2',
                                                                                'artists': 'artists2'})
sim_df.head(5)
# Out:
#                    track1                  track2  simscore          artists1  \
# 0  5vjLSffimiIP26QG5WcN2K  1EzrEOXmMH3G43AXT1y7pA  0.937620  Chord Overstreet
# 1  5vjLSffimiIP26QG5WcN2K  08MFgEQeVLF37EyZ7jcwLc  0.972169  Chord Overstreet
# 2  1EzrEOXmMH3G43AXT1y7pA  08MFgEQeVLF37EyZ7jcwLc  0.979727        Jason Mraz
# 3  5vjLSffimiIP26QG5WcN2K  4mzP5mHkRvGxdhdGdAH7EJ  0.991455  Chord Overstreet
# 4  1EzrEOXmMH3G43AXT1y7pA  4mzP5mHkRvGxdhdGdAH7EJ  0.962800        Jason Mraz
#
#                                 album1     song1    genre1      artists2  \
# 0                              Hold On   Hold On  acoustic    Jason Mraz
# 1                              Hold On   Hold On  acoustic  Zack Tabudlo
# 2  We Sing. We Dance. We Steal Things.  Im Yours  acoustic  Zack Tabudlo
# 3                              Hold On   Hold On  acoustic  Zack Tabudlo
# 4  We Sing. We Dance. We Steal Things.  Im Yours  acoustic  Zack Tabudlo
#
#                                 album2                 song2    genre2
# 0  We Sing. We Dance. We Steal Things.              Im Yours  acoustic
# 1                                 Pano                  Pano  acoustic
# 2                                 Pano                  Pano  acoustic
# 3                              Episode  Give Me Your Forever  acoustic
# 4                              Episode  Give Me Your Forever  acoustic

# %%
# export as csv
df.to_csv('spotify_test.csv')
